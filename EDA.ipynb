# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Fantasy-Premier-League/data/cleaned_merged_seasons.csv', index_col=0)
df
# Out:
# /tmp/ipykernel_4406/582200045.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Fantasy-Premier-League/data/cleaned_merged_seasons.csv', index_col=0)
#       season_x                name position       team_x  assists  bonus  bps  \
# 0      2016-17     Aaron Cresswell      DEF          NaN        0      0    0
# 1      2016-17        Aaron Lennon      MID          NaN        0      0    6
# 2      2016-17        Aaron Ramsey      MID          NaN        0      0    5
# 3      2016-17  Abdoulaye Doucouré      MID          NaN        0      0    0
# 4      2016-17        Adam Forshaw      MID          NaN        0      0    3
# ...        ...                 ...      ...          ...      ...    ...  ...
# 98397  2021-22       Wilfred Ndidi      MID    Leicester        0      0    0
# 98398  2021-22        Matt Ritchie      DEF    Newcastle        0      0    3
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
#       season_x                name position team_x  assists  bonus  bps  \
# 0      2016-17     Aaron Cresswell      DEF    NaN        0      0    0
# 1      2016-17        Aaron Lennon      MID    NaN        0      0    6
# 2      2016-17        Aaron Ramsey      MID    NaN        0      0    5
# 3      2016-17  Abdoulaye Doucouré      MID    NaN        0      0    0
# 4      2016-17        Adam Forshaw      MID    NaN        0      0    3
# ...        ...                 ...      ...    ...      ...    ...  ...
# 49467  2019-20      Yoshinori Muto      FWD    NaN        0      0    0
# 49468  2019-20     Youri Tielemans      MID    NaN        0      0   11
# 49469  2019-20       Yves Bissouma      MID    NaN        0      0   22
# 49470  2019-20      Çaglar Söyüncü      DEF    NaN        0      0    0
# 49471  2019-20        Ørjan Nyland       GK    NaN        0      0    0
#
#        clean_sheets  creativity  element  ...  team_h_score  threat  \
# ...

# %%
df.columns
# Out:
# Index(['season_x', 'name', 'position', 'team_x', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'fixture', 'goals_conceded',
#        'goals_scored', 'ict_index', 'influence', 'kickoff_time', 'minutes',
#        'opponent_team', 'opp_team_name', 'own_goals', 'penalties_missed',
#        'penalties_saved', 'red_cards', 'round', 'saves', 'selected',
#        'team_a_score', 'team_h_score', 'threat', 'total_points',
#        'transfers_balance', 'transfers_in', 'transfers_out', 'value',
#        'was_home', 'yellow_cards', 'GW'],
#       dtype='object')

# %%
plt.figure(figsize = (10, 10))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
cat_features = [
    'season_x', 
    'position'
]

# %%
cols = df.columns.tolist()
cols.remove('total_points')
cols = np.array(cols)
cols
# Out:
# array(['season_x', 'name', 'position', 'team_x', 'assists', 'bonus',
#        'bps', 'clean_sheets', 'creativity', 'element', 'fixture',
#        'goals_conceded', 'goals_scored', 'ict_index', 'influence',
#        'kickoff_time', 'minutes', 'opponent_team', 'opp_team_name',
#        'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards',
#        'round', 'saves', 'selected', 'team_a_score', 'team_h_score',
#        'threat', 'transfers_balance', 'transfers_in', 'transfers_out',
#        'value', 'was_home', 'yellow_cards', 'GW'], dtype='<U17')

# %% [markdown]
# # MAIN PROCESSING

# %%
final_df = df.sort_values(['name', 'season_x', 'GW']).set_index(['total_points', 'name'], drop = True).groupby('name', as_index=False).shift().dropna(subset = ['season_x']).reset_index()
final_df.columns
# Out:
# Index(['total_points', 'name', 'season_x', 'position', 'team_x', 'assists',
#        'bonus', 'bps', 'clean_sheets', 'creativity', 'element', 'fixture',
#        'goals_conceded', 'goals_scored', 'ict_index', 'influence',
#        'kickoff_time', 'minutes', 'opponent_team', 'opp_team_name',
#        'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards',
#        'round', 'saves', 'selected', 'team_a_score', 'team_h_score', 'threat',
#        'transfers_balance', 'transfers_in', 'transfers_out', 'value',
#        'was_home', 'yellow_cards', 'GW'],
#       dtype='object')

# %%
final_df[:10]
# Out:
#    total_points            name season_x position team_x  assists  bonus  \
# 0             1  Aaron Connolly  2019-20      FWD    NaN      0.0    0.0
# 1             1  Aaron Connolly  2019-20      FWD    NaN      0.0    0.0
# 2             1  Aaron Connolly  2019-20      FWD    NaN      0.0    0.0
# 3            13  Aaron Connolly  2019-20      FWD    NaN      0.0    0.0
# 4             1  Aaron Connolly  2019-20      FWD    NaN      0.0    3.0
# 5             8  Aaron Connolly  2019-20      FWD    NaN      0.0    0.0
# 6             2  Aaron Connolly  2019-20      FWD    NaN      2.0    0.0
# 7             1  Aaron Connolly  2019-20      FWD    NaN      0.0    0.0
# 8             0  Aaron Connolly  2019-20      FWD    NaN      0.0    0.0
# 9             2  Aaron Connolly  2019-20      FWD    NaN      0.0    0.0
#
#     bps  clean_sheets  creativity  ...  team_a_score  team_h_score  threat  \
# 0   1.0           0.0         0.1  ...           0.0           4.0     0.0
# ...

# %%
df_corr = final_df.corr()
plt.figure(figsize = (10, 10))
sns.heatmap(df_corr)
# Out:
# <AxesSubplot:>

# %%
list(df_corr[df_corr >= 0.9].where(np.triu(np.ones(df_corr.shape), k = 1).astype(np.bool8)).stack().index)
# Out:
# [('bps', 'influence'),
#  ('fixture', 'round'),
#  ('fixture', 'GW'),
#  ('round', 'GW')]

# %%
drop_features = [
    'fixture', 
    'round', 
    'bps'
]
