# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter, FuncFormatter
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading in the Dataset (Preprocess)

# %%
df = pd.read_csv('data/cleaned_merged_seasons.csv', index_col=0)
# df.head()

# %%
# PLot the percent of missing values per feature

missing_vals = (df.isna().sum()/df.shape[0])*100
ax = missing_vals.plot(kind='bar', color = 'red')
ax.set_title('Feature-wise missing values')
ax.set_ylabel('Logarithmic Percent Missing values')
ax.set_xlabel('Features')
ax.set_yscale("log")
plt.show()

# %%
# dropping team information
df = df.drop(columns=['team_x', 'fixture', 'kickoff_time'])
df = df.fillna(0)

# %%
# rearranging columns for better perception

columns = ['season_x', 'name', 'position', 'assists', 'bonus', 'bps',
           'clean_sheets', 'creativity', 'element', 'goals_conceded',
           'goals_scored', 'ict_index', 'influence', 'minutes',
           'opponent_team', 'opp_team_name', 'own_goals', 'penalties_missed',
           'penalties_saved', 'red_cards', 'round', 'saves', 'selected',
           'team_a_score', 'team_h_score', 'threat', 'total_points',
           'transfers_balance', 'transfers_in', 'transfers_out', 'value',
           'was_home', 'yellow_cards', 'GW']

new_columns = ['name', 'season_x', 'GW', 'position',  'assists', 'bonus', 'bps',
               'clean_sheets', 'creativity', 'element', 'goals_conceded',
               'goals_scored', 'ict_index', 'influence', 'minutes',
               'opponent_team', 'opp_team_name', 'own_goals', 'penalties_missed',
               'penalties_saved', 'red_cards', 'round', 'saves', 'selected',
               'team_a_score', 'team_h_score', 'threat',
               'transfers_balance', 'transfers_in', 'transfers_out', 'value',
               'was_home', 'yellow_cards',  'total_points']

df = df[new_columns]
# df.head()

# %%
# columns that need averaging
avg_columns = ['name', 'assists', 'bonus', 'bps', 'clean_sheets',
               'creativity', 'element', 'goals_conceded', 'goals_scored', 'ict_index',
               'influence', 'minutes', 'own_goals', 'penalties_missed',
               'penalties_saved', 'red_cards', 'round', 'saves', 'selected',
               'team_a_score', 'team_h_score', 'threat', 'transfers_balance',
               'transfers_in', 'transfers_out', 'value', 'was_home', 'yellow_cards']

# %%
# sorting data based on name, season and gameweek
df = df.sort_values(['name', 'season_x', 'GW']).reset_index(drop = True)
df.head()
# Out:
#              name season_x  GW position  assists  bonus  bps  clean_sheets  \
# 0  Aaron Connolly  2019-20   4      FWD        0      0    1             0
# 1  Aaron Connolly  2019-20   5      FWD        0      0    1             0
# 2  Aaron Connolly  2019-20   6      FWD        0      0    1             0
# 3  Aaron Connolly  2019-20   7      FWD        0      0    2             0
# 4  Aaron Connolly  2019-20   8      FWD        0      3   53             1
#
#    creativity  element  ...  team_a_score  team_h_score  threat  \
# 0         0.1      534  ...           0.0           4.0     0.0
# 1         0.3      534  ...           1.0           1.0    21.0
# 2         4.8      534  ...           0.0           0.0    18.0
# 3         0.6      534  ...           0.0           2.0     0.0
# 4        23.8      534  ...           0.0           3.0   107.0
#
#    transfers_balance  transfers_in  transfers_out value  was_home  \
# 0                  0             0              0    45     False
# 1              10589         13500           2911    45      True
# 2               8090         11749           3659    45     False
# 3               8437         13439           5002    45     False
# 4               2156          5952           3796    45      True
#
#    yellow_cards  total_points
# 0             0             1
# 1             0             1
# 2             0             1
# 3             0             1
# 4             0            13
#
# [5 rows x 34 columns]

# %%
# Dividing the data into features and target
X = df.loc[:, df.columns != 'total_points']
y = df.loc[:, ['name', 'total_points']]

X[avg_columns] = X[avg_columns].groupby('name', as_index=False).rolling(3, min_periods = 1).mean().reset_index(drop = True)
features = X.set_index(['name'], drop = True).groupby('name', as_index=True).shift().dropna().reset_index()
features
# Out:
#                  name season_x    GW position  assists  bonus        bps  \
# 0      Aaron Connolly  2019-20   4.0      FWD      0.0    0.0   1.000000
# 1      Aaron Connolly  2019-20   5.0      FWD      0.0    0.0   1.000000
# 2      Aaron Connolly  2019-20   6.0      FWD      0.0    0.0   1.000000
# 3      Aaron Connolly  2019-20   7.0      FWD      0.0    0.0   1.333333
# 4      Aaron Connolly  2019-20   8.0      FWD      0.0    1.0  18.666667
# ...               ...      ...   ...      ...      ...    ...        ...
# 97408    Ørjan Nyland  2020-21  34.0       GK      0.0    0.0   0.000000
# 97409    Ørjan Nyland  2020-21  35.0       GK      0.0    0.0   0.000000
# 97410    Ørjan Nyland  2020-21  35.0       GK      0.0    0.0   0.000000
# 97411    Ørjan Nyland  2020-21  36.0       GK      0.0    0.0   0.000000
# 97412    Ørjan Nyland  2020-21  37.0       GK      0.0    0.0   0.000000
#
#        clean_sheets  creativity  element  ...       selected  team_a_score  \
# 0          0.000000    0.100000    534.0  ...       0.000000      0.000000
# 1          0.000000    0.200000    534.0  ...    7014.500000      0.500000
# 2          0.000000    1.733333    534.0  ...   12277.666667      0.333333
# 3          0.000000    1.900000    534.0  ...   23177.333333      0.333333
# 4          0.333333    9.733333    534.0  ...   30176.333333      0.000000
# ...             ...         ...      ...  ...            ...           ...
# 97408      0.000000    0.000000     35.0  ...  281394.333333      2.000000
# 97409      0.000000    0.000000     35.0  ...  278999.000000      2.333333
# 97410      0.000000    0.000000     35.0  ...  277527.000000      1.666667
# 97411      0.000000    0.000000     35.0  ...  276053.000000      1.666667
# 97412      0.000000    0.000000     35.0  ...  275057.666667      1.333333
#
#        team_h_score     threat  transfers_balance  transfers_in transfers_out  \
# 0          4.000000   0.000000           0.000000      0.000000      0.000000
# 1          2.500000  10.500000        5294.500000   6750.000000   1455.500000
# 2          1.666667  13.000000        6226.333333   8416.333333   2190.000000
# 3          1.000000  13.000000        9038.666667  12896.000000   3857.333333
# 4          1.666667  41.666667        6227.666667  10380.000000   4152.333333
# ...             ...        ...                ...           ...           ...
# 97408      1.333333   0.000000       -2122.333333      0.000000   2122.333333
# 97409      1.333333   0.000000       -2346.666667      0.000000   2346.666667
# 97410      0.666667   0.000000       -2471.000000      0.000000   2471.000000
# 97411      1.333333   0.000000       -2426.000000      0.000000   2426.000000
# 97412      1.333333   0.000000       -2033.333333      0.000000   2033.333333
#
#        value  was_home  yellow_cards
# 0       45.0  0.000000           0.0
# 1       45.0  0.500000           0.0
# 2       45.0  0.333333           0.0
# 3       45.0  0.333333           0.0
# 4       45.0  0.333333           0.0
# ...      ...       ...           ...
# 97408   40.0  0.666667           0.0
# 97409   40.0  0.666667           0.0
# 97410   40.0  0.666667           0.0
# 97411   40.0  0.666667           0.0
# 97412   40.0  0.333333           0.0
#
# [97413 rows x 33 columns]

# %%
y = y.reset_index(drop = True)
target = y.groupby('name').apply(lambda group: group.iloc[1:, :]).reset_index(drop = True).drop(columns = ['name'])
target
# Out:
#        total_points
# 0                 1
# 1                 1
# 2                 1
# 3                13
# 4                 1
# ...             ...
# 97408             0
# 97409             0
# 97410             0
# 97411             0
# 97412             0
#
# [97413 rows x 1 columns]

# %%
df = pd.concat([features, target], axis = 1)
df.head()
# Out:
#              name season_x   GW position  assists  bonus        bps  \
# 0  Aaron Connolly  2019-20  4.0      FWD      0.0    0.0   1.000000
# 1  Aaron Connolly  2019-20  5.0      FWD      0.0    0.0   1.000000
# 2  Aaron Connolly  2019-20  6.0      FWD      0.0    0.0   1.000000
# 3  Aaron Connolly  2019-20  7.0      FWD      0.0    0.0   1.333333
# 4  Aaron Connolly  2019-20  8.0      FWD      0.0    1.0  18.666667
#
#    clean_sheets  creativity  element  ...  team_a_score  team_h_score  \
# 0      0.000000    0.100000    534.0  ...      0.000000      4.000000
# 1      0.000000    0.200000    534.0  ...      0.500000      2.500000
# 2      0.000000    1.733333    534.0  ...      0.333333      1.666667
# 3      0.000000    1.900000    534.0  ...      0.333333      1.000000
# 4      0.333333    9.733333    534.0  ...      0.000000      1.666667
#
#       threat  transfers_balance  transfers_in  transfers_out value  was_home  \
# 0   0.000000           0.000000      0.000000       0.000000  45.0  0.000000
# 1  10.500000        5294.500000   6750.000000    1455.500000  45.0  0.500000
# 2  13.000000        6226.333333   8416.333333    2190.000000  45.0  0.333333
# 3  13.000000        9038.666667  12896.000000    3857.333333  45.0  0.333333
# 4  41.666667        6227.666667  10380.000000    4152.333333  45.0  0.333333
#
#    yellow_cards  total_points
# 0           0.0             1
# 1           0.0             1
# 2           0.0             1
# 3           0.0            13
# 4           0.0             1
#
# [5 rows x 34 columns]

# %%
df = df.drop(columns = ['name', 'season_x', 'opponent_team', 'opp_team_name', 'GW', 'round'])

# %%
df
# Out:
#       position  assists  bonus        bps  clean_sheets  creativity  element  \
# 0          FWD      0.0    0.0   1.000000      0.000000    0.100000    534.0
# 1          FWD      0.0    0.0   1.000000      0.000000    0.200000    534.0
# 2          FWD      0.0    0.0   1.000000      0.000000    1.733333    534.0
# 3          FWD      0.0    0.0   1.333333      0.000000    1.900000    534.0
# 4          FWD      0.0    1.0  18.666667      0.333333    9.733333    534.0
# ...        ...      ...    ...        ...           ...         ...      ...
# 97408       GK      0.0    0.0   0.000000      0.000000    0.000000     35.0
# 97409       GK      0.0    0.0   0.000000      0.000000    0.000000     35.0
# 97410       GK      0.0    0.0   0.000000      0.000000    0.000000     35.0
# 97411       GK      0.0    0.0   0.000000      0.000000    0.000000     35.0
# 97412       GK      0.0    0.0   0.000000      0.000000    0.000000     35.0
#
#        goals_conceded  goals_scored  ict_index  ...  team_a_score  \
# 0            1.000000      0.000000   0.000000  ...      0.000000
# 1            1.000000      0.000000   1.100000  ...      0.500000
# 2            0.666667      0.000000   1.566667  ...      0.333333
# 3            0.666667      0.000000   1.600000  ...      0.333333
# 4            0.333333      0.666667   7.566667  ...      0.000000
# ...               ...           ...        ...  ...           ...
# 97408        0.000000      0.000000   0.000000  ...      2.000000
# 97409        0.000000      0.000000   0.000000  ...      2.333333
# 97410        0.000000      0.000000   0.000000  ...      1.666667
# 97411        0.000000      0.000000   0.000000  ...      1.666667
# 97412        0.000000      0.000000   0.000000  ...      1.333333
#
#        team_h_score     threat  transfers_balance  transfers_in  \
# 0          4.000000   0.000000           0.000000      0.000000
# 1          2.500000  10.500000        5294.500000   6750.000000
# 2          1.666667  13.000000        6226.333333   8416.333333
# 3          1.000000  13.000000        9038.666667  12896.000000
# 4          1.666667  41.666667        6227.666667  10380.000000
# ...             ...        ...                ...           ...
# 97408      1.333333   0.000000       -2122.333333      0.000000
# 97409      1.333333   0.000000       -2346.666667      0.000000
# 97410      0.666667   0.000000       -2471.000000      0.000000
# 97411      1.333333   0.000000       -2426.000000      0.000000
# 97412      1.333333   0.000000       -2033.333333      0.000000
#
#        transfers_out  value  was_home  yellow_cards  total_points
# 0           0.000000   45.0  0.000000           0.0             1
# 1        1455.500000   45.0  0.500000           0.0             1
# 2        2190.000000   45.0  0.333333           0.0             1
# 3        3857.333333   45.0  0.333333           0.0            13
# 4        4152.333333   45.0  0.333333           0.0             1
# ...              ...    ...       ...           ...           ...
# 97408    2122.333333   40.0  0.666667           0.0             0
# 97409    2346.666667   40.0  0.666667           0.0             0
# 97410    2471.000000   40.0  0.666667           0.0             0
# 97411    2426.000000   40.0  0.666667           0.0             0
# 97412    2033.333333   40.0  0.333333           0.0             0
#
# [97413 rows x 28 columns]

# %%
X_dev, X_test, y_dev, y_test = train_test_split(df.loc[:, df.columns != 'total_points'], 
                                                df.loc[:, 'total_points'], 
                                                random_state=42, 
                                                test_size = 0.2)

# X_train, X_val, y_train, y_val = train_test_split(X_dev,
#                                                   y_dev,
#                                                   random_state=42, 
#                                                   test_size = 0.25)

# %%
pd.concat([X_dev, y_dev], axis = 1).reset_index(drop = True).to_csv('dev.csv', index = False)

# %%
pd.concat([X_test, y_test], axis = 1).reset_index(drop = True).to_csv('test.csv', index = False)

# %%
X_dev.columns
# Out:
# Index(['position', 'assists', 'bonus', 'bps', 'clean_sheets', 'creativity',
#        'element', 'goals_conceded', 'goals_scored', 'ict_index', 'influence',
#        'minutes', 'own_goals', 'penalties_missed', 'penalties_saved',
#        'red_cards', 'saves', 'selected', 'team_a_score', 'team_h_score',
#        'threat', 'transfers_balance', 'transfers_in', 'transfers_out', 'value',
#        'was_home', 'yellow_cards'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Lets check for any missing values

# %%
# PLot the percent of missing values per feature

missing_vals = (df.isna().sum()/df.shape[0])*100
ax = missing_vals.plot(kind='bar')
ax.set_title('% missing values per column')
ax.set_ylabel('% missing values')
plt.show()

# %% [markdown]
# Let's analyze the features to see which ones are categorical versus which ones are numerical

# %%
# Find which features are numerical vs. categorical for EDA

num_vars = []
cat_vars = []
num_cat_vars = []

for column in list(df.columns): 
    
    if df[column].dtype == 'float64' and len(df[column].unique()) >= 10: 
        num_vars.append(column)
    elif df[column].dtype == 'float64': 
        num_cat_vars.append(column)
    else: 
        cat_vars.append(column)
        
    print("{} has {} unique values of type {}".format(column, len(df[column].unique()), df[column].dtype))

cat_vars.remove('total_points')
# Out:
# position has 4 unique values of type object
# assists has 9 unique values of type float64
# bonus has 12 unique values of type float64
# bps has 215 unique values of type float64
# clean_sheets has 5 unique values of type float64
# creativity has 8258 unique values of type float64
# element has 1776 unique values of type float64
# goals_conceded has 20 unique values of type float64
# goals_scored has 11 unique values of type float64
# ict_index has 3505 unique values of type float64
# influence has 5525 unique values of type float64
# minutes has 337 unique values of type float64
# own_goals has 5 unique values of type float64
# penalties_missed has 5 unique values of type float64
# penalties_saved has 3 unique values of type float64
# red_cards has 4 unique values of type float64
# saves has 31 unique values of type float64
# selected has 82417 unique values of type float64
# team_a_score has 21 unique values of type float64
# team_h_score has 25 unique values of type float64
# threat has 324 unique values of type float64
# transfers_balance has 44907 unique values of type float64
# transfers_in has 38114 unique values of type float64
# transfers_out has 41767 unique values of type float64
# value has 313 unique values of type float64
# was_home has 5 unique values of type float64
# yellow_cards has 5 unique values of type float64
# total_points has 31 unique values of type int64

# %% [markdown]
# Examining the distribution for numerical features, numerical features with a small number of categories, and categorical features  ...

# %%
# Examine the distribution for numerical features (floats with 10+ unique values)

hist = df.hist(column=num_vars, layout=(3, 7), figsize=(30, 15))
for ax, column_name in zip(hist.flatten(), sorted(num_vars)):
    ax.set_title("Distribution of {}".format(column_name))
    ax.set_xlabel(column_name)
    ax.set_ylabel('count')

# %%
# Examine the distribution for numerical categorical features (floats with <10 unique values)

hist = df.hist(column=num_cat_vars, layout=(3,3), figsize=(20,13))
for ax, column_name in zip(hist.flatten(), sorted(num_cat_vars)):
    ax.set_title("Distribution of {}".format(column_name))
    ax.set_xlabel(column_name)
    ax.set_ylabel('count')

# %%
# Examine the distribution for categorical features (non float datatypes that aren't any of the above)

fig, axes = plt.subplots(nrows=1,ncols=2, figsize=(10, 5))
for index, feature in enumerate(sorted(cat_vars)): 
    df[feature].value_counts().plot(ax=axes[index], subplots=True, kind='bar')
    axes[index].set_xlabel(feature)
    axes[index].set_ylabel('count')
    axes[index].set_title(f'Frequency plot for {feature}')
    
axes[1].remove()

# %%
# Examine the distribution of y-labels

df.hist(column='total_points')
plt.title('Distribution of total_points')
plt.xlabel('total_points')
plt.ylabel('count')
plt.show()

# %% [markdown]
# Let's look at the correlation between features and target ...

# %%
# Split into df_x and df_y

df_x = df.drop(columns=['total_points'])
df_y = df['total_points']

# %%
# Examine the correlation with the target for numerical features (floats with 10+ unique values)

fig, axes = plt.subplots(6, 3, figsize=(20,35))
plt.subplots_adjust(hspace=0.3)
for ax, feature in zip(axes.flatten(), sorted(num_vars)): 
    ax.scatter(df_x[feature], df_y)
    ax.set_xlabel(feature)
    ax.set_ylabel('total_points')
    ax.set_title(f'Relationship between {feature} and total_points')

# %%
[str(round(float(label.get_text()), 2)) for label in ax.get_xticklabels()]
# Out:
# ['20.0', '40.0', '60.0', '80.0', '100.0', '120.0', '140.0', '160.0']

# %%
# Examine the correlation with the target for numerical categorical features (floats with <10 unique values)
from matplotlib.ticker import StrMethodFormatter

fig, axes = plt.subplots(3, 3, figsize=(20,20))
plt.subplots_adjust(hspace = 0.3)

for ax, feature in zip(axes.flatten(), sorted(num_cat_vars)):
    df.boxplot(column=['total_points'], by=[feature], ax=ax)
    ax.set_xlabel(feature)
    ax.set_ylabel('total_points')
    ax.set_title(f'Relationship of {feature} with total_points')
    ax.set_xticklabels([str(round(float(label.get_text()), 2)) for label in ax.get_xticklabels()])
    
plt.suptitle('');
fig.delaxes(axes[2][2])

# %%
# Examine the correlation with the target for categorical features

fig, axes = plt.subplots(1, 2, figsize=(20,5))

for ax, feature in zip(axes.flatten(), sorted(cat_vars)): 
    df.boxplot(column=['total_points'], by=[feature], ax=ax)
    ax.set_xlabel(feature)
    ax.set_ylabel('total_points')
    ax.set_title(f'Relationship between {feature} and total_points')
    ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)

axes[1].remove()
plt.xticks(rotation = 90)
plt.suptitle('');

# %% [markdown]
# Let's look at highly correlated features

# %%
df_corr = df.corr()
df_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a1436_row0_col0, #T_a1436_row1_col1, #T_a1436_row2_col2, #T_a1436_row3_col3, #T_a1436_row4_col4, #T_a1436_row5_col5, #T_a1436_row6_col6, #T_a1436_row7_col7, #T_a1436_row8_col8, #T_a1436_row9_col9, #T_a1436_row10_col10, #T_a1436_row11_col11, #T_a1436_row12_col12, #T_a1436_row13_col13, #T_a1436_row14_col14, #T_a1436_row15_col15, #T_a1436_row16_col16, #T_a1436_row17_col17, #T_a1436_row18_col18, #T_a1436_row19_col19, #T_a1436_row20_col20, #T_a1436_row21_col21, #T_a1436_row22_col22, #T_a1436_row23_col23, #T_a1436_row24_col24, #T_a1436_row25_col25, #T_a1436_row26_col26 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a1436_row0_col1, #T_a1436_row2_col21, #T_a1436_row3_col19, #T_a1436_row19_col0, #T_a1436_row21_col4, #T_a1436_row23_col21 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_a1436_row0_col2, #T_a1436_row8_col16, #T_a1436_row19_col1, #T_a1436_row26_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_a1436_row0_col3, #T_a1436_row0_col16, #T_a1436_row6_col20, #T_a1436_row7_col3, #T_a1436_row14_col22, #T_a1436_row22_col10, #T_a1436_row25_col22 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_a1436_row0_col4, #T_a1436_row3_col8 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_a1436_row0_col5, #T_a1436_row4_col12, #T_a1436_row7_col5, #T_a1436_row11_col25, #T_a1436_row12_col0, #T_a1436_row17_col26, #T_a1436_row25_col18 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_a1436_row0_col6, #T_a1436_row3_col0, #T_a1436_row3_col7, #T_a1436_row18_col6 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_a1436_row0_col7, #T_a1436_row1_col6, #T_a1436_row4_col25, #T_a1436_row7_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_a1436_row0_col8, #T_a1436_row19_col10, #T_a1436_row21_col22 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_a1436_row0_col9, #T_a1436_row1_col10 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_a1436_row0_col10, #T_a1436_row1_col21, #T_a1436_row2_col23, #T_a1436_row19_col26, #T_a1436_row23_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_a1436_row0_col11, #T_a1436_row0_col13, #T_a1436_row2_col5, #T_a1436_row2_col14, #T_a1436_row3_col18, #T_a1436_row5_col14, #T_a1436_row7_col13, #T_a1436_row17_col24, #T_a1436_row20_col11, #T_a1436_row24_col11, #T_a1436_row25_col24, #T_a1436_row26_col24 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_a1436_row0_col12, #T_a1436_row13_col25, #T_a1436_row19_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_a1436_row0_col14, #T_a1436_row0_col24, #T_a1436_row1_col24, #T_a1436_row3_col14, #T_a1436_row9_col24, #T_a1436_row18_col11, #T_a1436_row18_col14, #T_a1436_row19_col11, #T_a1436_row20_col12, #T_a1436_row22_col13, #T_a1436_row24_col14, #T_a1436_row25_col14 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_a1436_row0_col15, #T_a1436_row3_col13, #T_a1436_row3_col24, #T_a1436_row4_col5, #T_a1436_row6_col5, #T_a1436_row7_col15, #T_a1436_row8_col11, #T_a1436_row8_col13, #T_a1436_row16_col5, #T_a1436_row18_col24 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_a1436_row0_col17, #T_a1436_row3_col15, #T_a1436_row6_col3, #T_a1436_row11_col6, #T_a1436_row18_col9, #T_a1436_row22_col0, #T_a1436_row25_col23 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_a1436_row0_col18, #T_a1436_row11_col9, #T_a1436_row12_col4, #T_a1436_row15_col1, #T_a1436_row18_col2 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_a1436_row0_col19, #T_a1436_row4_col1, #T_a1436_row4_col6 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_a1436_row0_col20, #T_a1436_row4_col26, #T_a1436_row15_col9 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_a1436_row0_col21, #T_a1436_row10_col15, #T_a1436_row21_col0, #T_a1436_row22_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_a1436_row0_col22, #T_a1436_row4_col7, #T_a1436_row6_col19 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_a1436_row0_col23, #T_a1436_row7_col10, #T_a1436_row26_col4, #T_a1436_row26_col19 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_a1436_row0_col25, #T_a1436_row13_col8, #T_a1436_row14_col23, #T_a1436_row17_col2, #T_a1436_row19_col17, #T_a1436_row21_col17, #T_a1436_row24_col2, #T_a1436_row24_col3 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_a1436_row0_col26, #T_a1436_row7_col6, #T_a1436_row24_col22, #T_a1436_row26_col7, #T_a1436_row26_col21 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_a1436_row1_col0, #T_a1436_row4_col16, #T_a1436_row16_col4, #T_a1436_row21_col1, #T_a1436_row26_col22 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_a1436_row1_col2, #T_a1436_row7_col19 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_a1436_row1_col3, #T_a1436_row3_col4, #T_a1436_row16_col9, #T_a1436_row23_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_a1436_row1_col4, #T_a1436_row9_col26, #T_a1436_row19_col16, #T_a1436_row21_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_a1436_row1_col5, #T_a1436_row10_col11, #T_a1436_row12_col15, #T_a1436_row12_col25, #T_a1436_row14_col15, #T_a1436_row17_col15, #T_a1436_row22_col14 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_a1436_row1_col7 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_a1436_row1_col8, #T_a1436_row22_col16 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_a1436_row1_col9 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_a1436_row1_col11, #T_a1436_row3_col11, #T_a1436_row5_col13, #T_a1436_row7_col11, #T_a1436_row8_col5, #T_a1436_row11_col24, #T_a1436_row12_col24, #T_a1436_row14_col13, #T_a1436_row14_col24, #T_a1436_row15_col4, #T_a1436_row16_col11, #T_a1436_row16_col24, #T_a1436_row17_col11, #T_a1436_row21_col11, #T_a1436_row22_col11, #T_a1436_row23_col24, #T_a1436_row24_col12, #T_a1436_row26_col14 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_a1436_row1_col12, #T_a1436_row5_col15, #T_a1436_row9_col11, #T_a1436_row11_col21, #T_a1436_row14_col7, #T_a1436_row25_col15, #T_a1436_row26_col12 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_a1436_row1_col13, #T_a1436_row9_col13, #T_a1436_row11_col4, #T_a1436_row13_col26, #T_a1436_row14_col4, #T_a1436_row18_col26, #T_a1436_row22_col18, #T_a1436_row24_col18, #T_a1436_row24_col19 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_a1436_row1_col14, #T_a1436_row5_col3, #T_a1436_row10_col24, #T_a1436_row11_col13, #T_a1436_row12_col13, #T_a1436_row12_col14, #T_a1436_row13_col14, #T_a1436_row17_col12, #T_a1436_row17_col13, #T_a1436_row18_col12, #T_a1436_row24_col13 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_a1436_row1_col15, #T_a1436_row13_col10, #T_a1436_row18_col23, #T_a1436_row26_col15, #T_a1436_row26_col25 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_a1436_row1_col16, #T_a1436_row23_col10 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_a1436_row1_col17, #T_a1436_row5_col17, #T_a1436_row8_col15, #T_a1436_row13_col23, #T_a1436_row14_col2, #T_a1436_row14_col3, #T_a1436_row16_col18, #T_a1436_row17_col16, #T_a1436_row25_col17, #T_a1436_row26_col17 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_a1436_row1_col18, #T_a1436_row2_col13, #T_a1436_row7_col12, #T_a1436_row12_col21, #T_a1436_row20_col15, #T_a1436_row22_col15 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_a1436_row1_col19 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_a1436_row1_col20, #T_a1436_row7_col20, #T_a1436_row8_col20, #T_a1436_row9_col16 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_a1436_row1_col22, #T_a1436_row3_col20, #T_a1436_row4_col20, #T_a1436_row10_col20, #T_a1436_row26_col3 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_a1436_row1_col23, #T_a1436_row19_col6, #T_a1436_row26_col23 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_a1436_row1_col25, #T_a1436_row2_col18, #T_a1436_row12_col6, #T_a1436_row13_col3, #T_a1436_row16_col17, #T_a1436_row17_col10, #T_a1436_row18_col0, #T_a1436_row18_col5, #T_a1436_row18_col7, #T_a1436_row18_col16, #T_a1436_row19_col12, #T_a1436_row21_col25, #T_a1436_row25_col0 {
#   background-color: #6a8bef;
#   color: #f1f1

# %%
# heatmap of correlation matrix
df_corr = df.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(df_corr, cmap=sns.diverging_palette(220, 20, as_cmap=True))

# Take a loot at the most highly correlated features
df_corr[df_corr >= 0.85].where(np.triu(np.ones(df_corr.shape), k = 1).astype(np.bool8)).stack()
# Out:
# bps        influence    0.934918
#            minutes      0.856918
# ict_index  influence    0.850082
#            threat       0.864673
# dtype: float64

# %%
# Take a loot at the most highly correlated features
df_corr[df_corr >= 0.85].where(np.triu(np.ones(df_corr.shape), k = 1).astype(np.bool8)).stack()
# Out:
# bps        influence    0.934918
#            minutes      0.856918
# ict_index  influence    0.850082
#            threat       0.864673
# dtype: float64

# %% [markdown]
# # Let's try to apply some models on the raw data (purely on individual player data)

# %% [markdown]
# We'll start with decision trees becuase these handle categorical features on the fly

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
# Get rid of any non-individual statistics or statistics that don't capture player performance
non_individual_stats = ['name', 'season_x', 'kickoff_time', 'opponent_team', 'opp_team_name', 'team_a_score', 'team_h_score', 'GW']
df_x = df_x.drop(columns=non_individual_stats, errors='ignore')

# Split the dataset into train and test using STRUCTURED SPLITTING
x_dev, x_test, y_dev, y_test = train_test_split(df_x, df_y, test_size = 0.2, shuffle=False)

# %%
# Fit the random forest classifier
preprocess = make_column_transformer((OneHotEncoder(handle_unknown="ignore"), ['position']), remainder="passthrough")
pipe = make_pipeline(preprocess, RandomForestRegressor(max_depth=15))
pipe.fit(X_dev, y_dev)

# Test accuracies on the most recent 20% of data
y_pred = pipe.predict(X_test)

print("Mean Absolute Error: " + str(mean_absolute_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1.3655864292835125

# %%
# Build the list of feature names
ohe_feature_names = preprocess.named_transformers_["onehotencoder"].get_feature_names().tolist()
ohe_feature_names = [x[3:] for x in ohe_feature_names]
feature_names = ohe_feature_names + list(df.loc[:, df.columns!='total_points'].drop(columns=['position']).columns)

# Get the importance of features
feat_imps = zip(feature_names, pipe[1].feature_importances_)
feats, imps = zip(*(sorted(list(filter(lambda x: x[1] != 0, feat_imps)), key=lambda x: x[1], reverse=True)))

# Plot the results
ax = sns.barplot(list(feats), list(imps))
ax.tick_params(axis='x', rotation=90)
ax.set_title('Feature Importances for Random Forest Pipe')
ax.set_ylabel('Feature Importance')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso

# %%
# Search coefficients as a function of alpha values

alphas = np.linspace(0.01,100,100)
lasso = Lasso(max_iter=1000)
coefs = []

for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(preprocess.transform(X_dev), y_dev)
    coefs.append(lasso.coef_)

# %%
# Plot the results (still needs to be cleaned up/formatted better)

plt.figure(figsize=(8,12))
ax = plt.gca()
ax.plot(alphas, coefs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('Standardized Coefficients')
plt.title('Lasso coefficients as a function of alpha')
plt.legend(feature_names, loc = 'upper right')

# %%
for i in range(len(feature_names)):
    for j in range(100):
        if coefs[j][i] == 0:
            print("Feature {} weights 0 at alpha = {}".format(feature_names[i],alphas[j]))
            break
# Out:
# Feature DEF weights 0 at alpha = 1.02
# Feature FWD weights 0 at alpha = 0.01
# Feature GK weights 0 at alpha = 0.01
# Feature MID weights 0 at alpha = 0.01
# Feature assists weights 0 at alpha = 0.01
# Feature bonus weights 0 at alpha = 1.02
# Feature bps weights 0 at alpha = 7.08
# Feature clean_sheets weights 0 at alpha = 1.02
# Feature creativity weights 0 at alpha = 3.04
# Feature goals_conceded weights 0 at alpha = 1.02
# Feature goals_scored weights 0 at alpha = 1.02
# Feature ict_index weights 0 at alpha = 1.02
# Feature own_goals weights 0 at alpha = 0.01
# Feature penalties_missed weights 0 at alpha = 0.01
# Feature penalties_saved weights 0 at alpha = 0.01
# Feature red_cards weights 0 at alpha = 0.01
# Feature saves weights 0 at alpha = 1.02
# Feature team_a_score weights 0 at alpha = 1.02
# Feature team_h_score weights 0 at alpha = 1.02
# Feature transfers_balance weights 0 at alpha = 2.03
# Feature value weights 0 at alpha = 6.07
# Feature was_home weights 0 at alpha = 0.01
# Feature yellow_cards weights 0 at alpha = 0.01

# %%
tmp = []
for i in range(len(feature_names)):
    if coefs[1][i] != 0:
        tmp.append(feature_names[i])
print(tmp)
# Out:
# ['bps', 'creativity', 'selected', 'transfers_balance', 'transfers_in', 'transfers_out', 'value']

# %%
pipe = make_pipeline(preprocess, Lasso(alpha = 1.02))
pipe.fit(X_dev, y_dev)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['position'])])),
#                 ('lasso', Lasso(alpha=1.02))])

# %%
plt.figure()
sns.barplot(y = pipe[1].coef_, x = feature_names)
plt.xticks(rotation = 90)
plt.xlabel('Features')
plt.ylabel('Coefficients')
plt.title('Feature Importance using Lasso')
# Out:
# Text(0.5, 1.0, 'Feature Importance using Lasso')
